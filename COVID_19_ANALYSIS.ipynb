# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
obj1=pd.read_csv('patients.csv',encoding='unicode_escape')
print(obj1)
obj2=obj1['agebracket'].dropna()
obj2
# Out:
#       agebracket  ... typeoftransmission
# 0            NaN  ...                NaN
# 1            NaN  ...                NaN
# 2            NaN  ...                NaN
# 3            NaN  ...                NaN
# 4            NaN  ...                NaN
# ...          ...  ...                ...
# 14734         24  ...           Imported
# 14735         45  ...           Imported
# 14736        NaN  ...           Imported
# 14737        NaN  ...           Imported
# 14738         20  ...           Imported
#
# [14739 rows x 20 columns]
# 31       39
# 32       42
# 33       65
# 34       48
# 35       65
#          ..
# 14732    55
# 14733    69
# 14734    24
# 14735    45
# 14738    20
# Name: agebracket, Length: 1621, dtype: object

# %%
sns.set(style='darkgrid',font='roman')
plt.figure(figsize=(100,100))
sns.relplot(x='agebracket',y='patientnumber',data=obj1,size=None,height=10)
plt.yticks(rotation=90)
plt.xticks(rotation=90)
plt.xlim(0,None)
plt.ylim(0,None)
# Out:
# (0.0, 15443.35)
